# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,  LSTM
from keras import metrics
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('nikkei.csv', encoding="shift_jis")
L = len(df)
Y = df.iloc[:, 4]  # 終値の列のみ抽出する。
Y = np.array(Y)  # numpy配列に変換する。
Y = Y.reshape(-1, 1)  # 行列に変換する。（配列の要素数行×1列）

import matplotlib.pyplot as plt
plt.plot(Y)

# %%
df.head()
# Out:
#            日付        始値        高値        安値        終値
# 0   2018/11/9  22471.31  22494.58  22226.01  22250.25
# 1  2018/11/12  22121.70  22324.01  22046.29  22269.88
# 2  2018/11/13  21885.24  21892.29  21484.65  21810.52
# 3  2018/11/14  21851.13  21990.41  21764.88  21846.48
# 4  2018/11/15  21670.35  21818.73  21613.53  21803.62

# %%
X1 = Y[0:L-3, :]  # 予測対象日の3日前のデータ
X2 = Y[1:L-2, :]  # 予測対象日の2日前のデータ
X3 = Y[2:L-1, :]  # 予測対象日の前日データ
Y = Y[3:L, :]  # 予測対象日のデータ
X = np.concatenate([X1, X2, X3], axis=1)  # numpy配列を結合する。

# %%
scaler = MinMaxScaler()  # データを0～1の範囲にスケールするための関数。
scaler.fit(X)  # スケーリングに使用する最小／最大値を計算する。
X = scaler.transform(X)  # Xをを0～1の範囲にスケーリングする。
scaler1 = MinMaxScaler()  # データを0～1の範囲にスケールするための関数。
scaler1.fit(Y)  # スケーリングに使用する最小／最大値を計算する。
Y = scaler1.transform(Y)  # Yをを0～1の範囲にスケーリングする。

# %%
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))  # 3次元配列に変換する。
# train, testデータを定義
X_train = X[:190, :, :]
X_test = X[190:, :, :]
Y_train = Y[:190, :]
Y_test = Y[190:, :]

# %%
model = Sequential()
model.add(LSTM(10, activation = 'tanh', input_shape = (1,3), recurrent_activation= 'hard_sigmoid'))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error', optimizer = 'rmsprop', metrics=[metrics.mae])
model.fit(X_train, Y_train, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 6/6 - 3s - loss: 0.4393 - mean_absolute_error: 0.6379
# Epoch 2/100
# 6/6 - 0s - loss: 0.3911 - mean_absolute_error: 0.6011
# Epoch 3/100
# 6/6 - 0s - loss: 0.3570 - mean_absolute_error: 0.5729
# Epoch 4/100
# 6/6 - 0s - loss: 0.3278 - mean_absolute_error: 0.5479
# Epoch 5/100
# 6/6 - 0s - loss: 0.3013 - mean_absolute_error: 0.5240
# Epoch 6/100
# 6/6 - 0s - loss: 0.2765 - mean_absolute_error: 0.5010
# Epoch 7/100
# 6/6 - 0s - loss: 0.2529 - mean_absolute_error: 0.4785
# Epoch 8/100
# 6/6 - 0s - loss: 0.2308 - mean_absolute_error: 0.4558
# Epoch 9/100
# 6/6 - 0s - loss: 0.2099 - mean_absolute_error: 0.4339
# Epoch 10/100
# 6/6 - 0s - loss: 0.1900 - mean_absolute_error: 0.4120
# Epoch 11/100
# 6/6 - 0s - loss: 0.1713 - mean_absolute_error: 0.3902
# Epoch 12/100
# 6/6 - 0s - loss: 0.1537 - mean_absolute_error: 0.3684
# Epoch 13/100
# 6/6 - 0s - loss: 0.1372 - mean_absolute_error: 0.3466
# Epoch 14/100
# 6/6 - 0s - loss: 0.1218 - mean_absolute_error: 0.3251
# Epoch 15/100
# 6/6 - 0s - loss: 0.1072 - mean_absolute_error: 0.3037
# Epoch 16/100
# 6/6 - 0s - loss: 0.0937 - mean_absolute_error: 0.2821
# Epoch 17/100
# 6/6 - 0s - loss: 0.0812 - mean_absolute_error: 0.2605
# Epoch 18/100
# 6/6 - 0s - loss: 0.0697 - mean_absolute_error: 0.2390
# Epoch 19/100
# 6/6 - 0s - loss: 0.0593 - mean_absolute_error: 0.2184
# Epoch 20/100
# 6/6 - 0s - loss: 0.0498 - mean_absolute_error: 0.1971
# Epoch 21/100
# 6/6 - 0s - loss: 0.0414 - mean_absolute_error: 0.1772
# Epoch 22/100
# 6/6 - 0s - loss: 0.0340 - mean_absolute_error: 0.1582
# Epoch 23/100
# 6/6 - 0s - loss: 0.0277 - mean_absolute_error: 0.1410
# Epoch 24/100
# 6/6 - 0s - loss: 0.0223 - mean_absolute_error: 0.1252
# Epoch 25/100
# 6/6 - 0s - loss: 0.0180 - mean_absolute_error: 0.1116
# Epoch 26/100
# 6/6 - 0s - loss: 0.0146 - mean_absolute_error: 0.0994
# Epoch 27/100
# 6/6 - 0s - loss: 0.0122 - mean_absolute_error: 0.0904
# Epoch 28/100
# 6/6 - 0s - loss: 0.0106 - mean_absolute_error: 0.0834
# Epoch 29/100
# 6/6 - 0s - loss: 0.0096 - mean_absolute_error: 0.0792
# Epoch 30/100
# 6/6 - 0s - loss: 0.0091 - mean_absolute_error: 0.0763
# Epoch 31/100
# 6/6 - 0s - loss: 0.0088 - mean_absolute_error: 0.0742
# Epoch 32/100
# 6/6 - 0s - loss: 0.0086 - mean_absolute_error: 0.0728
# Epoch 33/100
# 6/6 - 0s - loss: 0.0084 - mean_absolute_error: 0.0717
# Epoch 34/100
# 6/6 - 0s - loss: 0.0081 - mean_absolute_error: 0.0708
# Epoch 35/100
# 6/6 - 0s - loss: 0.0078 - mean_absolute_error: 0.0694
# Epoch 36/100
# 6/6 - 0s - loss: 0.0076 - mean_absolute_error: 0.0680
# Epoch 37/100
# 6/6 - 0s - loss: 0.0074 - mean_absolute_error: 0.0666
# Epoch 38/100
# 6/6 - 0s - loss: 0.0071 - mean_absolute_error: 0.0660
# Epoch 39/100
# 6/6 - 0s - loss: 0.0069 - mean_absolute_error: 0.0642
# Epoch 40/100
# 6/6 - 0s - loss: 0.0067 - mean_absolute_error: 0.0635
# Epoch 41/100
# 6/6 - 0s - loss: 0.0065 - mean_absolute_error: 0.0618
# Epoch 42/100
# 6/6 - 0s - loss: 0.0063 - mean_absolute_error: 0.0613
# Epoch 43/100
# 6/6 - 0s - loss: 0.0061 - mean_absolute_error: 0.0602
# Epoch 44/100
# 6/6 - 0s - loss: 0.0060 - mean_absolute_error: 0.0588
# Epoch 45/100
# 6/6 - 0s - loss: 0.0058 - mean_absolute_error: 0.0578
# Epoch 46/100
# 6/6 - 0s - loss: 0.0056 - mean_absolute_error: 0.0568
# Epoch 47/100
# 6/6 - 0s - loss: 0.0054 - mean_absolute_error: 0.0554
# Epoch 48/100
# 6/6 - 0s - loss: 0.0053 - mean_absolute_error: 0.0551
# Epoch 49/100
# 6/6 - 0s - loss: 0.0051 - mean_absolute_error: 0.0539
# Epoch 50/100
# 6/6 - 0s - loss: 0.0050 - mean_absolute_error: 0.0529
# Epoch 51/100
# 6/6 - 0s - loss: 0.0049 - mean_absolute_error: 0.0519
# Epoch 52/100
# 6/6 - 0s - loss: 0.0047 - mean_absolute_error: 0.0508
# Epoch 53/100
# 6/6 - 0s - loss: 0.0047 - mean_absolute_error: 0.0503
# Epoch 54/100
# 6/6 - 0s - loss: 0.0046 - mean_absolute_error: 0.0506
# Epoch 55/100
# 6/6 - 0s - loss: 0.0045 - mean_absolute_error: 0.0491
# Epoch 56/100
# 6/6 - 0s - loss: 0.0044 - mean_absolute_error: 0.0489
# Epoch 57/100
# 6/6 - 0s - loss: 0.0044 - mean_absolute_error: 0.0490
# Epoch 58/100
# 6/6 - 0s - loss: 0.0043 - mean_absolute_error: 0.0482
# Epoch 59/100
# 6/6 - 0s - loss: 0.0042 - mean_absolute_error: 0.0477
# Epoch 60/100
# 6/6 - 0s - loss: 0.0041 - mean_absolute_error: 0.0472
# Epoch 61/100
# 6/6 - 0s - loss: 0.0040 - mean_absolute_error: 0.0466
# Epoch 62/100
# 6/6 - 0s - loss: 0.0040 - mean_absolute_error: 0.0470
# Epoch 63/100
# 6/6 - 0s - loss: 0.0039 - mean_absolute_error: 0.0465
# Epoch 64/100
# 6/6 - 0s - loss: 0.0039 - mean_absolute_error: 0.0464
# Epoch 65/100
# 6/6 - 0s - loss: 0.0038 - mean_absolute_error: 0.0462
# Epoch 66/100
# 6/6 - 0s - loss: 0.0038 - mean_absolute_error: 0.0458
# Epoch 67/100
# 6/6 - 0s - loss: 0.0038 - mean_absolute_error: 0.0454
# Epoch 68/100
# 6/6 - 0s - loss: 0.0037 - mean_absolute_error: 0.0452
# Epoch 69/100
# 6/6 - 0s - loss: 0.0038 - mean_absolute_error: 0.0455
# Epoch 70/100
# 6/6 - 0s - loss: 0.0037 - mean_absolute_error: 0.0452
# Epoch 71/100
# 6/6 - 0s - loss: 0.0037 - mean_absolute_error: 0.0447
# Epoch 72/100
# 6/6 - 0s - loss: 0.0037 - mean_absolute_error: 0.0454
# Epoch 73/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0445
# Epoch 74/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0444
# Epoch 75/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0450
# Epoch 76/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0446
# Epoch 77/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0443
# Epoch 78/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0443
# Epoch 79/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0443
# Epoch 80/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0451
# Epoch 81/100
# 6/6 - 0s - loss: 0.0036 - mean_absolute_error: 0.0444
# Epoch 82/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0443
# Epoch 83/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0441
# Epoch 84/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0443
# Epoch 85/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0442
# Epoch 86/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0443
# Epoch 87/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0434
# Epoch 88/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0445
# Epoch 89/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0440
# Epoch 90/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0438
# Epoch 91/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0442
# Epoch 92/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0438
# Epoch 93/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0439
# Epoch 94/100
# 6/6 - 0s - loss: 0.0035 - mean_absolute_error: 0.0439
# Epoch 95/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0437
# Epoch 96/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0439
# Epoch 97/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0435
# Epoch 98/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0435
# Epoch 99/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0438
# Epoch 100/100
# 6/6 - 0s - loss: 0.0034 - mean_absolute_error: 0.0438

# %%
Predict = model.predict(X_test)

# オリジナルのスケールに戻す、タイムインデックスを付ける。
Y_train = scaler1.inverse_transform(Y_train)
Y_train = pd.DataFrame(Y_train)
Y_train.index = pd.to_datetime(df.iloc[3:193,0])
Y_test = scaler1.inverse_transform(Y_test)
Y_test = pd.DataFrame(Y_test)
Y_test.index = pd.to_datetime(df.iloc[193:,0])
Predict = scaler1.inverse_transform(Predict)
Predict = pd.DataFrame(Predict)
Predict.index=pd.to_datetime(df.iloc[193:,0])
plt.figure(figsize=(15,10))
plt.plot(Y_test, label = 'Test')
plt.plot(Predict, label = 'Prediction')
plt.legend(loc='best')
plt.show()
