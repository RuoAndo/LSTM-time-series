# %%
import numpy as np

rand = np.random.rand()  # 一つの乱数
print(rand)
# 0.5399711080561779

arr = np.random.rand(3)  # サイズが3の配列の乱数
print(arr)
# [ 0.22393312  0.56723404  0.41167989]

arr = np.random.rand(4, 4)  # 4 x 4の配列の乱数
print(arr)
# [[ 0.98109413  0.43272792  0.78808567  0.14697466]
#  [ 0.14529422  0.66417579  0.62020433  0.39887021]
#  [ 0.78762131  0.3616854   0.76995665  0.25530529]
#  [ 0.59426681  0.64130992  0.41451061  0.2356074 ]]

arr = np.random.rand(100)  # 3 x 2 x 2の配列の乱数
print(arr)
# [[[ 0.26072665  0.63424568]
#   [ 0.43025675  0.88787556]]
#
#  [[ 0.58189813  0.57733422]
#   [ 0.4312518   0.12558879]]
#
#  [[ 0.58588003  0.58290714]
#   [ 0.58133023  0.05894161]]]
# Out:
# 0.028435958654714377
# [0.01687874 0.26644073 0.53700885]
# [[0.84732914 0.92214669 0.11846318 0.821825  ]
#  [0.81880858 0.26908909 0.02935257 0.51562019]
#  [0.76575235 0.369884   0.97847988 0.39820763]
#  [0.17142825 0.4705372  0.95358545 0.31378967]]
# [0.65794661 0.00682699 0.50898335 0.2985422  0.70883812 0.27090558
#  0.88923013 0.0980566  0.73999242 0.3539317  0.68658456 0.07312395
#  0.32776933 0.12811557 0.04778745 0.71288401 0.06788176 0.56815214
#  0.01094361 0.13969065 0.57366787 0.19612261 0.43120994 0.64747762
#  0.20925081 0.15338041 0.44594322 0.74952    0.98669766 0.83180657
#  0.73004124 0.79200476 0.90840662 0.23284878 0.1831279  0.51141997
#  0.64247942 0.80989361 0.10429103 0.99986581 0.16364225 0.49860608
#  0.25209198 0.52198272 0.62333291 0.79602443 0.46724103 0.68965392
#  0.2325242  0.61728409 0.92693426 0.53142946 0.99089693 0.57191212
#  0.08827627 0.21997367 0.40960176 0.19409767 0.99980147 0.70410778
#  0.20747647 0.38823082 0.21373293 0.10344624 0.15289707 0.9428375
#  0.61126108 0.42333842 0.69737541 0.89872581 0.59899281 0.46637571
#  0.8118619  0.1136231  0.48073027 0.9465045  0.17811553 0.97641925
#  0.25235235 0.6348883  0.97849112 0.77497362 0.86346247 0.35207402
#  0.6259799  0.25365173 0.17334625 0.76449668 0.91543651 0.87961419
#  0.82572048 0.68510892 0.9847755  0.15196645 0.36112617 0.89260777
#  0.96585565 0.1693025  0.82380928 0.61607356]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
import dateutil

# %%
plt.plot(arr)

# %%
s1 = np.random.randn(1000)

# %%
plt.plot(s1)

# %%
s1 = np.random.normal(loc=0, scale=np.sqrt(2), size=1000)

# %%
plt.plot(s1)

# %%
plt.hist(s1, bins='auto')#xをヒストグラムにプロットする。ヒストグラムの本数は'auto'
plt.show()#グラフを表示
