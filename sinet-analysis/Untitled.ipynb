# %%
import pandas as pd

# %%
df = pd.read_csv("month.csv", header=None, names=["time","counts","span"])

# %% [markdown]
# UNIX時間を標準時に変更

# %%
import datetime

# %%
df['time'] = pd.to_datetime(df['time'].astype(int), unit='s')

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as md
import dateutil

plt.figure(figsize=(24, 8), dpi=50)
plt.plot(df['time'], df['counts'])

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
Q = df['counts']

# %%
import statsmodels.api as sm
res = sm.tsa.seasonal_decompose(Q, freq=7)

plt.figure(figsize=(24, 8), dpi=50)
res.plot()

plt.rcParams["figure.figsize"] = (8, 6)
# Out:
# <ipython-input-21-5eb470e9ac14>:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   res = sm.tsa.seasonal_decompose(Q, freq=7)
# <statsmodels.tsa.seasonal.DecomposeResult object at 0x000001AA3B118850>
